# %% [markdown]
# # Code 5
# - Combine all Strategy
#   - Missing Value Imputation
#   - Outlier Startegy
#   - Tranformation Strategy

# %% [markdown]
# ## 1/ Import Libraries

# %%
#CodeSection1
from google.colab import drive
drive.mount('/mntDrive')
# Out:
# Mounted at /mntDrive

# %%
#CodeSection2
import pandas as pd
import numpy as np

# %% [markdown]
# ## 2/ Import Data

# %%
#CodeSection3
train = pd.read_csv('/mntDrive/MyDrive/__Data_Science/2 Cross Sell Prediction/input/train.csv')
test = pd.read_csv('/mntDrive/MyDrive/__Data_Science/2 Cross Sell Prediction/input/test.csv')

# %% [markdown]
# ## 3/ Combine both Datasets (train, test)

# %%
#CodeSection4
all_data = [train, test]

# %% [markdown]
# ### Check Combined Data
# - Missing Value
# - Data Types

# %%
#CodeSection5
# Combine both to check Missing Value
pd.concat([train, test], axis = 0).isnull().sum()
# Out:
# id                           0
# Gender                       0
# Age                          0
# Driving_License              0
# Region_Code                  0
# Previously_Insured           0
# Vehicle_Age                  0
# Vehicle_Damage               0
# Annual_Premium               0
# Policy_Sales_Channel         0
# Vintage                      0
# Response                127037
# dtype: int64

# %%
#CodeSection6
# Check Data types for each variable
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    381109 non-null  int64
#  1   Gender                381109 non-null  object
#  2   Age                   381109 non-null  int64
#  3   Driving_License       381109 non-null  int64
#  4   Region_Code           381109 non-null  float64
#  5   Previously_Insured    381109 non-null  int64
#  6   Vehicle_Age           381109 non-null  object
#  7   Vehicle_Damage        381109 non-null  object
#  8   Annual_Premium        381109 non-null  float64
#  9   Policy_Sales_Channel  381109 non-null  float64
#  10  Vintage               381109 non-null  int64
#  11  Response              381109 non-null  int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 34.9+ MB

# %% [markdown]
# ## 4/ Numerical Processing

# %% [markdown]
# ### 4.1/ Impute Numerical Variables

# %%
#CodeSection7
# Identify all Numerical features
numerical = ['Age', 'Annual_Premium', 'Vintage']

# %%
#CodeSection8
# Import SimpleImputer
<Write your code here>

# %%
#CodeSection9

#Initiate SimpleImputer
num_impute = <Write your code here>

# Fit SimpleImputer on Numerical Features
<Write your code here>
# Out:
#   File "<ipython-input-9-03b87a9dfa71>", line 4
#     num_impute = <Write your code here>
#                  ^
# SyntaxError: invalid syntax

# %%
#CodeSection10
# Impute Train and Test
<Write your code here>

# %% [markdown]
# ### 4.2/ Outlier Strategy

# %%
#CodeSection11

# Write a loop to detect and impute Outliers
for num_var in numerical:
  Q1 = train[num_var].quantile(0.25)
  Q3 = train[num_var].quantile(0.75)

  IQR = Q3-Q1

  Lower_Whisker = Q1 - 1.5*IQR
  Upper_Whisker = Q3 + 1.5*IQR

  for dataset in all_data:
    dataset[num_var] = dataset[num_var].apply(lambda x : Upper_Whisker if x > Upper_Whisker else x)

# %% [markdown]
# ### 4.3/ Transformation Strategy

# %%
#CodeSection12
# Import StandardScaler
from sklearn.preprocessing import StandardScaler

# %%
#CodeSection13

#Initiate StandardScaler
num_scale = StandardScaler()

# Fit StandardScaler
num_scale.fit(train[numerical])
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
#CodeSection14
# Scale Train and Test
for dataset in all_data:
  dataset[numerical] = num_scale.transform(dataset[numerical])

# %% [markdown]
# ## 5/ Impute Categorical Variables

# %% [markdown]
# ### Impute all Categorical Variables at once

# %%
#CodeSection15
# Identify all Categorical Features

# %%
#CodeSection16
# Import SimpleImputer
<Write your code here>

# %%
#CodeSection17

#Initiate SimpleImputer
cat_impute = <Write your code here>

# Fit SimpleImputer
<Write your code here>
# Out:
# SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#               missing_values=nan, strategy='most_frequent', verbose=0)

# %%
#CodeSection18
# Impute Train and Test
<Write your code here>

# %% [markdown]
# ## 6/ Now Re Check all Features

# %%
#CodeSection19
# Combine both to check Missing Value
pd.concat([train, test], axis = 0).isnull().sum()
# Out:
# id                           0
# Gender                       0
# Age                          0
# Driving_License              0
# Region_Code                  0
# Previously_Insured           0
# Vehicle_Age                  0
# Vehicle_Damage               0
# Annual_Premium               0
# Policy_Sales_Channel         0
# Vintage                      0
# Response                127037
# dtype: int64

# %% [markdown]
# ## 8/ Prepare Data for Model Model

# %%
#CodeSection20
# Check First 5 Rows of Test Data
test.head()
# Out:
#        id Gender       Age  ...  Annual_Premium  Policy_Sales_Channel   Vintage
# 0  381110   Male -0.891113  ...        0.364286                 152.0 -1.211258
# 1  381111   Male  0.075906  ...        0.233506                   7.0 -0.518068
# 2  381112   Male  0.527181  ...        0.639803                 124.0  0.533668
# 3  381113   Male -0.955581  ...        0.465731                 152.0  0.390249
# 4  381114   Male -0.762177  ...        1.870517                 152.0  1.704919
#
# [5 rows x 11 columns]

# %%
#CodeSection21
# Get X and y Variables for your Dataset
X = train.drop(['id','Response'], axis =  1)
y = train['Response']

# %% [markdown]
# ### Create Dummy Variables for  Categorical Variables

# %%
#CodeSection22
# Get Dummy Variables
X = pd.get_dummies(X, drop_first = True)  # Keep only n - 1 Variables - Use "drop_first = True"

# %% [markdown]
# ## 9/ Build Model

# %%
#CodeSection23
#Import Logistic Regression Library
from sklearn.linear_model import LogisticRegression

#Initialize LR
clf = LogisticRegression(max_iter = 1000, class_weight = 'balanced')

# %%
#CodeSection24
# Fit Model
model = clf.fit(X, y)

# %% [markdown]
# ### Check Accuracy of Model on Train Data

# %%
#CodeSection25
# Predict on Train Data
y_pred = model.predict(X)

# %% [markdown]
# ### We can use a Accuracy Function from Metrics
# - Check Train Accuracy

# %%
#CodeSection26
# Import metrics library
from sklearn.metrics import accuracy_score

# %%
#CodeSection27
# get Actual "y" variables (use "y_true" as variable)
y_true = y

# %%
#CodeSection28
# Print Train Accuracy
print(f" Train Accuracy : {accuracy_score(y_true, y_pred):0.1%}")
# Out:
#  Train Accuracy : 63.9%

# %% [markdown]
# ## 10/ Predict and Submit

# %% [markdown]
# ### Predict

# %%
#CodeSection29
# Get all the X Variables from the Test Dataset
X_test = test.drop(['id'], axis =  1)

# %%
#CodeSection30
#Covert to Dummies
X_test = pd.get_dummies(X_test, drop_first = True)

# %%
#CodeSection31
# use this code if the next Code shows error
#X_test['Married_Missing']  = 0

# %%
#CodeSection32
# Predict on X_test Data ("X_test_prep")
X_test_prep = model.predict(X_test)

# %% [markdown]
# ### Create Submission File

# %%
#CodeSection33
submission = pd.DataFrame({
    'id' : test['id'],
    'Response' : X_test_prep
})

# %% [markdown]
# ### Export Submission File

# %%
#CodeSection34
submission.to_csv('/mntDrive/MyDrive/__Data_Science/2 Cross Sell Prediction/output/O5_Preproccesing_All_balanced.csv', index = False)

# %%
# LB Accuracy : 0.7777
